# %%
import sys
sys.path.append("../")
import plot
import video

# %%
# crop out the black bands 
video_slice = video.read_video("../data/mario-trim.mov")[:,50:750,:,:]
# shape is like <time,height,width,RGB>
video_slice.shape

# %%
resized = video.resize_video(video_slice)
# Out:
# 100%|██████████████████████████████████████| 1874/1874 [00:08<00:00, 233.72it/s]

# %%
# show an example plot
fig = plot.plate_fig(resized[0,:,:,:])

# %%
matrix = resized[0,:,:,0]
"""
df_plate = matrix_to_plate(resized_for_animation[0,:,:,0])
df_flat = pandas.melt(df_plate.reset_index(),id_vars="Row",var_name="Column")
df_flat.insert(loc=0,column="Well",value=[ f"{r}{c}" for r,c in zip(df_flat["Row"],df_flat["Column"])])
df_flat.sort_values(by="Well",inplace=True)
"""
# Out:
# '\ndf_plate = matrix_to_plate(resized_for_animation[0,:,:,0])\ndf_flat = pandas.melt(df_plate.reset_index(),id_vars="Row",var_name="Column")\ndf_flat.insert(loc=0,column="Well",value=[ f"{r}{c}" for r,c in zip(df_flat["Row"],df_flat["Column"])])\ndf_flat.sort_values(by="Well",inplace=True)\n'

# %%
image = resized[0,:,:,:]

# %%
fig, axs, ims = plot.flat_vs_matrix_figure(matrix=resized[0,:,:,:],animated=True)

# %%
video.save_comparison_video(frames=resized,file_name="mario.gif",fps=20,verbose=True)
# Out:
# Frame 0001/1874
# Frame 0002/1874
# Frame 0003/1874
# Frame 0004/1874
# Frame 0005/1874
# Frame 0006/1874
# Frame 0007/1874
# Frame 0008/1874
# Frame 0009/1874
# Frame 0010/1874
# Frame 0011/1874
# Frame 0012/1874
# Frame 0013/1874
# Frame 0014/1874
# Frame 0015/1874
# Frame 0016/1874
# Frame 0017/1874
# Frame 0018/1874
# Frame 0019/1874
# Frame 0020/1874
# Frame 0021/1874
# Frame 0022/1874
# Frame 0023/1874
# Frame 0024/1874
# Frame 0025/1874
# Frame 0026/1874
# Frame 0027/1874
# Frame 0028/1874
# Frame 0029/1874
# Frame 0030/1874
# Frame 0031/1874
# Frame 0032/1874
# Frame 0033/1874
# Frame 0034/1874
# Frame 0035/1874
# Frame 0036/1874
# Frame 0037/1874
# Frame 0038/1874
# Frame 0039/1874
# Frame 0040/1874
# Frame 0041/1874
# Frame 0042/1874
# Frame 0043/1874
# Frame 0044/1874
# Frame 0045/1874
# Frame 0046/1874
# Frame 0047/1874
# Frame 0048/1874
# Frame 0049/1874
# Frame 0050/1874
# Frame 0051/1874
# Frame 0052/1874
# Frame 0053/1874
# Frame 0054/1874
# Frame 0055/1874
# ...
